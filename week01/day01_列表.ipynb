# %%
list = ['zero','one','two']
print(list[2])
# Out:
# two

# %%
list = ['zero','one','two']
print(list[-1])
# Out:
# two

# %%
nums =['10','20','30','40','50']
print(nums[0:4])
# Out:
# ['10', '20', '30', '40']

# %%
nums =['10','20','30','40','50']
print(nums[-3:-1])
# Out:
# ['30', '40']

# %%
nums =['10','20','30','40','50']
print('nums:',nums[1:-1])
# Out:
# nums: ['20', '30', '40']

# %%
nums =['10','20','30','40','50']
print('nums:',nums[1:-1])
print('nums1:',nums[0:-2])
# Out:
# nums: ['20', '30', '40']
# nums1: ['10', '20', '30']

# %%
nums =['10','20','30','40','50']
print('第三个元素为:',list[2])
list[2] = 300
print('更新后的第三个元素为:',list[2])
nums1  = ['10','20','30','40','50']
nums1.append('60')
print('更新后的列表为：',nums1)
# Out:
# 第三个元素为: two
# 更新后的第三个元素为: 300
# 更新后的列表为： ['10', '20', '30', '40', '50', '60']

# %%
nums =['10','20','30','40','50']

print('原始列表：',nums)
del nums[2]
print('删除第三个元素：',nums)
# Out:
# 原始列表： ['10', '20', '30', '40', '50']
# 删除第三个元素： ['10', '20', '40', '50']

# %%
'10' in ['10','20','30','40','50']
# Out:
# True

# %%
for x in [1,2,3,4]:print(x,end=" ")
# Out:
# 1 2 3 4

# %%
[1234]*10
# Out:
# [1234, 1234, 1234, 1234, 1234, 1234, 1234, 1234, 1234, 1234]

# %%
[1234]+[456]
# Out:
# [1234, 456]

# %%
123+456
# Out:
# 579

# %%
len([123,234,123])
# Out:
# 3

# %%
L = [1,2,3,4,5]
L += [6,7,8,9]
L
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
L = [123]
print(L)
# Out:
# [123]

# %%
l = [123]
l
# Out:
# [123]

# %%
a = [1,2,3]
b = ['q','w','e']
x = [a,b]
x[1][2]
# Out:
# 'e'

# %%
a = [1,1,1,1,1]
a.count(1)
# Out:
# 5

# %%
a = [1,1,1,1,1]
len(a)
# Out:
# 5

# %%
a = [1,2,3,4,5]
print(max(a),min(a))
# Out:
# 5 1

# %%
a = [1,2,3,4,5]
for x in a: print(x,end='fuck')
# Out:
# 1fuck2fuck3fuck4fuck5fuck

# %%
a = [1,2,3,4,5]
b = [6,7,8,9,0]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
a = ['one','two','three','four','one']
a.index('two')
# Out:
# 1

# %%
a = [1,2,3,4,5,6]
a.insert(1,2)
a
# Out:
# [1, 2, 2, 3, 4, 5, 6]

# %%
a = [1,2,3,4,5]
a.pop()
a
# Out:
# [1, 2, 3, 4]

# %%
a = [1,1,1,1,1]
a.remove(1)
a
# Out:
# [1, 1, 1, 1]

# %%
a = [1,2,3,4,5,6]
a.reverse()
a
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
a = [21341,12331,86752]
a.sort()
a
# Out:
# [12331, 21341, 86752]

# %%
a = [21341,12331,86752]
a.sort(reverse=True)
a
# Out:
# [86752, 21341, 12331]
